# %% [markdown]
# # Week3授業前課題2 住宅情報の分析

# %% [markdown]
# ## 【問題1】データセットの取得
# 【問題1】データセットの取得
# pd.read_csv()を使用して、変数に格納してください。

# %%
"""
pandas を使用するので pandas をインポート
指定の通り、csv ファイルを読み込む。またcsvファイルは事前にDLしておく
read_csv（） の引数にcsvファイル名を指定する
"""
import pandas as pd
X = pd.read_csv('train.csv')
X.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## 【問題2】データセット自体の調査
# KaggleのOverviewページや、Dataページの「Data fields」などを読みながら、どのようなデータセットかを説明してください。

# %%
"""
極端にいうと住宅情報が集められたデータセットである。
住所や建てられた日、改造日や材質など、住宅に関するあらゆる情報がまとめられている。
"""
# Out:
# '\n極端にいうと住宅情報が集められたデータセットである。\n住所や建てられた日、改造日や材質など、住宅に関するあらゆる情報がまとめられている。\n'

# %% [markdown]
# ## 【問題3】データの確認
# データを確認していきます。コードとマークダウンを組み合わせてレポートしてください。

# %%
"""
各特徴量がどういったものかを見る。（数値データか文字データなど）
.dtypesというメソッドを使用すると各列のデータ型が確認できる！
"""
"""
https://note.nkmk.me/python-numpy-dtype-astype/
int64 符号あり64ビット整数型
float64 倍精度浮動小数点型（符号部1ビット、指数部11ビット、仮数部52ビット）
object Pythonオブジェクト型
"""
X.dtypes.head()
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# dtype: object

# %%
"""
今回の目的変数はどの列か確認する。
https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
を翻訳した所、ターゲット変数（目的変数）は「SalePrice」と書かれている。
"""
# Out:
# '\n今回の目的変数はどの列か確認する。\nhttps://www.kaggle.com/c/house-prices-advanced-regression-techniques/data\nを翻訳した所、ターゲット変数（目的変数）は「SalePrice」と書かれている。\n'

# %%
"""
特徴量の平均値と標準偏差、四分位数を一度に表示させる。
"""
X.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ## 【問題4】欠損値への対応
# 欠損値に関して以下のことを行い、レポートしてください。

# %%
"""
各特徴量の欠損値の有無を確認する。
"""
X.isnull()

# それぞれどれ位欠損しているかを確認する
X.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# dtype: int64

# %%
"""
欠損値の確認にはmissingnoというライブラリを活用しましょう。
このライブラリにより欠損値の有無が可視化できます。
インストールや使い方に関しては以下のページをご覧ください。

ResidentMario/missingno: Missing data visualization module for Python.

ひとまず、言われた通りmissingnoをインストールや
ライブラリを使用して状態を確認する。
"""
# X.info() #データの情報を知れる
import missingno as msno
msno.matrix(X)

# %%
msno.heatmap(X)

# %%
"""
欠損値が何パーセント含まれるかを確認する。＞調査したらなんか出てきたので表示させるw
"""
def nullchousa(df):
    for i in df.columns:
        print("■■■  " + i )
        print("NULL数:" + str(df[i].isnull().sum() )+
                 "　　　　NULL率:" + str((df[i].isnull().sum()/len(df)).round(3)) +
                 "    データの種類数:" + str(df[i].value_counts().count()))

nullchousa(X)
### ヒートマップは全然関係無かった
# msno.heatmap(X)
# Out:
# ■■■  Id
# NULL数:0　　　　NULL率:0.0    データの種類数:1460
# ■■■  MSSubClass
# NULL数:0　　　　NULL率:0.0    データの種類数:15
# ■■■  MSZoning
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  LotFrontage
# NULL数:259　　　　NULL率:0.177    データの種類数:110
# ■■■  LotArea
# NULL数:0　　　　NULL率:0.0    データの種類数:1073
# ■■■  Street
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  Alley
# NULL数:1369　　　　NULL率:0.938    データの種類数:2
# ■■■  LotShape
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  LandContour
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  Utilities
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  LotConfig
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  LandSlope
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  Neighborhood
# NULL数:0　　　　NULL率:0.0    データの種類数:25
# ■■■  Condition1
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  Condition2
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  BldgType
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  HouseStyle
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  OverallQual
# NULL数:0　　　　NULL率:0.0    データの種類数:10
# ■■■  OverallCond
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  YearBuilt
# NULL数:0　　　　NULL率:0.0    データの種類数:112
# ■■■  YearRemodAdd
# NULL数:0　　　　NULL率:0.0    データの種類数:61
# ■■■  RoofStyle
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  RoofMatl
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  Exterior1st
# NULL数:0　　　　NULL率:0.0    データの種類数:15
# ■■■  Exterior2nd
# NULL数:0　　　　NULL率:0.0    データの種類数:16
# ■■■  MasVnrType
# NULL数:8　　　　NULL率:0.005    データの種類数:4
# ■■■  MasVnrArea
# NULL数:8　　　　NULL率:0.005    データの種類数:327
# ■■■  ExterQual
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  ExterCond
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  Foundation
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  BsmtQual
# NULL数:37　　　　NULL率:0.025    データの種類数:4
# ■■■  BsmtCond
# NULL数:37　　　　NULL率:0.025    データの種類数:4
# ■■■  BsmtExposure
# NULL数:38　　　　NULL率:0.026    データの種類数:4
# ■■■  BsmtFinType1
# NULL数:37　　　　NULL率:0.025    データの種類数:6
# ■■■  BsmtFinSF1
# NULL数:0　　　　NULL率:0.0    データの種類数:637
# ■■■  BsmtFinType2
# NULL数:38　　　　NULL率:0.026    データの種類数:6
# ■■■  BsmtFinSF2
# NULL数:0　　　　NULL率:0.0    データの種類数:144
# ■■■  BsmtUnfSF
# NULL数:0　　　　NULL率:0.0    データの種類数:780
# ■■■  TotalBsmtSF
# NULL数:0　　　　NULL率:0.0    データの種類数:721
# ■■■  Heating
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  HeatingQC
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  CentralAir
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  Electrical
# NULL数:1　　　　NULL率:0.001    データの種類数:5
# ■■■  1stFlrSF
# NULL数:0　　　　NULL率:0.0    データの種類数:753
# ■■■  2ndFlrSF
# NULL数:0　　　　NULL率:0.0    データの種類数:417
# ■■■  LowQualFinSF
# NULL数:0　　　　NULL率:0.0    データの種類数:24
# ■■■  GrLivArea
# NULL数:0　　　　NULL率:0.0    データの種類数:861
# ■■■  BsmtFullBath
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  BsmtHalfBath
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  FullBath
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  HalfBath
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  BedroomAbvGr
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  KitchenAbvGr
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  KitchenQual
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  TotRmsAbvGrd
# NULL数:0　　　　NULL率:0.0    データの種類数:12
# ■■■  Functional
# NULL数:0　　　　NULL率:0.0    データの種類数:7
# ■■■  Fireplaces
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  FireplaceQu
# NULL数:690　　　　NULL率:0.473    データの種類数:5
# ■■■  GarageType
# NULL数:81　　　　NULL率:0.055    データの種類数:6
# ■■■  GarageYrBlt
# NULL数:81　　　　NULL率:0.055    データの種類数:97
# ■■■  GarageFinish
# NULL数:81　　　　NULL率:0.055    データの種類数:3
# ■■■  GarageCars
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  GarageArea
# NULL数:0　　　　NULL率:0.0    データの種類数:441
# ■■■  GarageQual
# NULL数:81　　　　NULL率:0.055    データの種類数:5
# ■■■  GarageCond
# NULL数:81　　　　NULL率:0.055    データの種類数:5
# ■■■  PavedDrive
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  WoodDeckSF
# NULL数:0　　　　NULL率:0.0    データの種類数:274
# ■■■  OpenPorchSF
# NULL数:0　　　　NULL率:0.0    データの種類数:202
# ■■■  EnclosedPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:120
# ■■■  3SsnPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:20
# ■■■  ScreenPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:76
# ■■■  PoolArea
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  PoolQC
# NULL数:1453　　　　NULL率:0.995    データの種類数:3
# ■■■  Fence
# NULL数:1179　　　　NULL率:0.808    データの種類数:4
# ■■■  MiscFeature
# NULL数:1406　　　　NULL率:0.963    データの種類数:4
# ■■■  MiscVal
# NULL数:0　　　　NULL率:0.0    データの種類数:21
# ■■■  MoSold
# NULL数:0　　　　NULL率:0.0    データの種類数:12
# ■■■  YrSold
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  SaleType
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  SaleCondition
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  SalePrice
# NULL数:0　　　　NULL率:0.0    データの種類数:663

# %%
"""
ヒント
5つ以上欠損値がある特徴量（列）は削除する。 .dropna＞行の間違えじゃない？？
pandas + XXX
"""
# X.dropna(how='any',axis=1) #nullが含まれる行を削除する
# X.dropna(axis=1) #nullが含まれる行を削除する

# X.dropna(subset=['LotFrontage']['Alley']['MasVnrType'])

# ５件以上欠損値がある列を弾くと全部の行が弾かれた。（列を削除したいんだってば！！）
# X.dropna(subset=['LotFrontage','Alley','MasVnrType','MasVnrArea','BsmtQual',
#                  'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
#                  'FireplaceQu','GarageType','GarageYrBlt','GarageFinish',
#                 'GarageQual','GarageCond','PoolQC','Fence','MiscFeature'])

# 非欠損値の数を数えて削除する。この場合であれば非欠損値が５個以上あればそのレコードは残す。という書き方。
X.dropna(thresh=5).head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
"""
欠損値があるサンプル（行）は削除する。 
dropna()メソッドを使うと出来る！！
axis=0,how='any'を指定すると欠損値を含む全ての列を削除する！
"""
X.dropna(axis=0,how='any')
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 81 columns]

# %% [markdown]
# ## 【問題5】用語の調査
# 以下の２つの単語を知る必要があります。これらを調査してまとめてください。
#
# 尖度
# 歪度

# %%
"""
# 尖度（せんど）
尖度（せんど、英: kurtosis)は、確率変数の確率密度関数や頻度分布の鋭さを表す数字である。
正規分布と比べて、尖度が大きければ鋭いピークと長く太い裾を持った分布を持ち、
尖度が小さければより丸みがかったピークと短く細い尾を持った分布であるという事が判断できる。

# 歪度（わいど）
「歪度」とは、分布の歪み度合いを示すものです。 
正規分布のように左右対称であるのか、それとも片方の裾だけだ伸びたような歪んだ分布なのか、その度合いを示します。 
これを歪度（または歪度係数）といって、歪度が0 よりも大きければ右の裾が長い分布、
歪度が0 よりも小さければ左の裾が長い分布となります。
"""
# Out:
# '\n# 尖度（せんど）\n尖度（せんど、英: kurtosis)は、確率変数の確率密度関数や頻度分布の鋭さを表す数字である。\n正規分布と比べて、尖度が大きければ鋭いピークと長く太い裾を持った分布を持ち、\n尖度が小さければより丸みがかったピークと短く細い尾を持った分布であるという事が判断できる。\n\n# 歪度（わいど）\n「歪度」とは、分布の歪み度合いを示すものです。 \n正規分布のように左右対称であるのか、それとも片方の裾だけだ伸びたような歪んだ分布なのか、その度合いを示します。 \nこれを歪度（または歪度係数）といって、歪度が0 よりも大きければ右の裾が長い分布、\n歪度が0 よりも小さければ左の裾が長い分布となります。\n'

# %% [markdown]
# ## 【問題6】分布の確認

# %%
"""
seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。
http://pynote.hatenablog.com/entry/seaborn-histogram
調査して簡単なやり方が見つかったのでとりあえずサンプルを見つけた
seaborn をインポートして .distplot() 関数を使うイメージ
sns.distplot(X)ってやったらエラー。
カラム名を入れる必要があった。dfを突っ込んだからどのカラムか分からないでコケたと推察。
"""
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np
# sns.set()

# x = np.random.randn(1000)
# sns.distplot(x)

y = X["SalePrice"]
sns.distplot(X.SalePrice)

# %%
import scipy
y_skew = scipy.stats.skew(y)
y_kurtosis = scipy.stats.kurtosis(y)
print("歪度：{}".format(y_skew))
print("尖度：{}".format(y_kurtosis))
# Out:
# 歪度：1.880940746034036
# 尖度：6.509812011089439

# %%
"""
目的変数に対して対数変換を行う。
そもそも対数変換ってなに？？w対数変換するもよく分からなかったけど、やり方は分かった。
https://qiita.com/ynakayama/items/2c3782c82317f21596ba
"""
import pylab as pl
# pl.hist(X.SalePrice)

Xh = X.SalePrice.apply(np.log)
Xh
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
# 5       11.870600
# 6       12.634603
# 7       12.206073
# 8       11.774520
# 9       11.678440
# 10      11.771436
# 11      12.751300
# 12      11.877569
# 13      12.540758
# 14      11.964001
# 15      11.790557
# 16      11.911702
# 17      11.407565
# 18      11.976659
# 19      11.842229
# 20      12.692503
# 21      11.845103
# 22      12.345835
# 23      11.774520
# 24      11.944708
# 25      12.454104
# 26      11.811547
# 27      12.631340
# 28      12.242887
# 29      11.134589
#           ...
# 1430    12.165980
# 1431    11.875831
# 1432    11.074421
# 1433    12.136187
# 1434    11.982929
# 1435    12.066811
# 1436    11.699405
# 1437    12.885671
# 1438    11.916389
# 1439    12.190959
# 1440    12.160029
# 1441    11.913713
# 1442    12.644328
# 1443    11.703546
# 1444    12.098487
# 1445    11.767568
# 1446    11.969717
# 1447    12.388394
# 1448    11.626254
# 1449    11.429544
# 1450    11.820410
# 1451    12.567551
# 1452    11.884489
# 1453    11.344507
# 1454    12.128111
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1460, dtype: float64

# %%
"""
対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。
上記の Xh を元に分布を作成する。
また、「尖度」と「歪度」も算出する。これはさっきのsns.distplot(X.SalePrice)で出せそう。
あれ？Xhの「尖度」と「歪度」を出せば終わりじゃない？？
"""
sns.distplot(Xh)

# %%
y_skew = scipy.stats.skew(Xh)
y_kurtosis = scipy.stats.kurtosis(Xh)
print("歪度：{}".format(y_skew))
print("尖度：{}".format(y_kurtosis))
# Out:
# 歪度：0.1212103673013655
# 尖度：0.8026555069117713

# %%
"""
対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。
このように加工することで予測時の精度を上げることができます。
seaborn.distplot — seaborn 0.9.0 documentation
●対数変換の前
歪度が左に寄っており、正規分布という意味では少し離れている。
●対数変換の後
歪度が正規分布に近づいた。
"""
# Out:
# '\n対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。\nこのように加工することで予測時の精度を上げることができます。\nseaborn.distplot — seaborn 0.9.0 documentation\n●対数変換の前\n歪度が左に寄っており、正規分布という意味では少し離れている。\n●対数変換の後\n歪度が正規分布に近づいた。\n'

# %% [markdown]
# ## 【問題7】相関係数の確認
# 特徴量の確認をしていきます。それぞれに対してマークダウンで説明や考察を書いてください。

# %%
"""
相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。

●考えた事
はじめに相関係数行列を算出。＞.corrで相関係数行列を作成する。
その後、算出した相関係数行列のヒートマップを出力する。

ヒートマップを見て、相関係数の高いものを探す。
YearBuiltとGarageYrbltの相関係数が高そう！！

# 相関係数行列を出力する
https://note.nkmk.me/python-pandas-corr/

# heatmap の日本語リファレンスっぽいやつ
https://pythondatascience.plavox.info/seaborn/heatmap

# heatmap のオプション
https://stats.biopapyrus.jp/python/heatmap.html

# heatmap の大きくする方法
https://codeday.me/jp/qa/20190323/465958.html
"""
plt.figure(figsize=(20, 20)) # heatmap の大きさを変更出来る！！すげー！！
X_soukan = X.corr(method='pearson')
sns.heatmap(X_soukan, # データをセット
            vmax=1, # 
            vmin=-1,
            center=0,
#             annot=True, # 数値が出るけど小さ過ぎて良く分からない。。
            square=True, # 正方形になる
            cmap='RdYlGn_r', # 色の指定をする（他のは未調査）
            linewidths=0.5, # 感覚の余白ラインの太さ
           )

# %%
# 目的関数に対して高い相関を持った特徴量を10個選んで heatmap にして出力
train_hc = X_soukan.loc[:,["OverallQual","GarageCars","GarageArea",
                           "GrLivArea","TotalBsmtSF","1stFlrSF",
                           "TotRmsAbvGrd","YearRemodAdd","YearBuilt",
                           "MasVnrArea"]]
train_hc_corr = train_hc.corr()
sns.heatmap(train_hc_corr)

# %%
"""
目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。

SalePrice が目的変数なので、（heatmapの一番下の行）これの相関が高い特徴量を10個選ぶ。
見た目でも良いが算出する方法があるか？？

# Filter Method の説明、特徴量の上位を選ぶ的な話。ただ、これだと別の話？？
https://qiita.com/shimopino/items/5fee7504c7acf044a521
"""
# Filetr Method の解析をする為にライブラリ？をインポートする
# from sklearn.model_selection import train_test_split
# from sklearn.feature_selection import VarianceThreshold

# 分散がゼロのデータは削除
# sel = VarianceThreshold(threshold=0)
# X_soukan_sel = sel.fit(Xsoukan)
# print(X_soukan_sel)
# sns.heatmap(sel)

# sns.pairplot(Xsoukan, hue='SalePrice')
# pg = sns.pairplot(X)
# print(type(pg))

# sns.heatmap(Xsoukan.SalePrice)

X_corr = X.corr()
# sns.heatmap(X_soukan, # データをセット
#            )
X_corr.head()
# Out:
#                    Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id           1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass   0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea     -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual -0.028365    0.032628     0.251646  0.105806     1.000000
#
#              OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id              0.012609  -0.012713     -0.021998   -0.050298   -0.005024
# MSSubClass     -0.059316   0.027850      0.040581    0.022936   -0.069836
# LotFrontage    -0.059213   0.123349      0.088866    0.193458    0.233633
# LotArea        -0.005636   0.014228      0.013788    0.104160    0.214103
# OverallQual    -0.091932   0.572323      0.550684    0.411876    0.239666
#
#                ...      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id             ...       -0.029643    -0.000477       0.002889  -0.046635
# MSSubClass     ...       -0.012579    -0.006100      -0.012037  -0.043825
# LotFrontage    ...        0.088521     0.151972       0.010700   0.070029
# LotArea        ...        0.171698     0.084774      -0.018340   0.020423
# OverallQual    ...        0.238923     0.308819      -0.113937   0.030371
#
#              ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# Id              0.001330  0.057044 -0.006242  0.021172  0.000712  -0.021917
# MSSubClass     -0.026030  0.008283 -0.007683 -0.013585 -0.021407  -0.084284
# LotFrontage     0.041383  0.206167  0.003368  0.011200  0.007450   0.351799
# LotArea         0.043160  0.077672  0.038068  0.001205 -0.014261   0.263843
# OverallQual     0.064886  0.065166 -0.031406  0.070815 -0.027347   0.790982
#
# [5 rows x 38 columns]

# %%
X_corr.loc['SalePrice'].head()
# Out:
# Id            -0.021917
# MSSubClass    -0.084284
# LotFrontage    0.351799
# LotArea        0.263843
# OverallQual    0.790982
# Name: SalePrice, dtype: float64

# %%
X_corr.loc['SalePrice'].sort_values().head()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# Name: SalePrice, dtype: float64

# %%
X_corr.loc['SalePrice'].sort_values()[-11:-1].head()
# Out:
# YearRemodAdd    0.507101
# YearBuilt       0.522897
# TotRmsAbvGrd    0.533723
# FullBath        0.560664
# 1stFlrSF        0.605852
# Name: SalePrice, dtype: float64

# %%
d=X_corr.loc['SalePrice'].sort_values()[-11: ]
d.index
# Out:
# Index(['YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd', 'FullBath', '1stFlrSF',
#        'TotalBsmtSF', 'GarageArea', 'GarageCars', 'GrLivArea', 'OverallQual',
#        'SalePrice'],
#       dtype='object')

# %%
top_list=d.index
top_list=list(top_list)
top_list
# Out:
# ['YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual',
#  'SalePrice']

# %%
df_number = X.select_dtypes(include='number')
df_number.loc[: , top_list].head()
# Out:
#    YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  TotalBsmtSF  \
# 0          2003       2003             8         2       856          856
# 1          1976       1976             6         2      1262         1262
# 2          2002       2001             6         2       920          920
# 3          1970       1915             7         1       961          756
# 4          2000       2000             9         2      1145         1145
#
#    GarageArea  GarageCars  GrLivArea  OverallQual  SalePrice
# 0         548           2       1710            7     208500
# 1         460           2       1262            6     181500
# 2         608           2       1786            7     223500
# 3         642           3       1717            7     140000
# 4         836           3       2198            8     250000

# %%
df_top=df_number.ix[: , top_list]
df_top.corr()
# Out:
# /Users/tominagashuuji/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#               YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  \
# YearRemodAdd      1.000000   0.592855      0.191740  0.439046  0.240379
# YearBuilt         0.592855   1.000000      0.095589  0.468271  0.281986
# TotRmsAbvGrd      0.191740   0.095589      1.000000  0.554784  0.409516
# FullBath          0.439046   0.468271      0.554784  1.000000  0.380637
# 1stFlrSF          0.240379   0.281986      0.409516  0.380637  1.000000
# TotalBsmtSF       0.291066   0.391452      0.285573  0.323722  0.819530
# GarageArea        0.371600   0.478954      0.337822  0.405656  0.489782
# GarageCars        0.420622   0.537850      0.362289  0.469672  0.439317
# GrLivArea         0.287389   0.199010      0.825489  0.630012  0.566024
# OverallQual       0.550684   0.572323      0.427452  0.550600  0.476224
# SalePrice         0.507101   0.522897      0.533723  0.560664  0.605852
#
#               TotalBsmtSF  GarageArea  GarageCars  GrLivArea  OverallQual  \
# YearRemodAdd     0.291066    0.371600    0.420622   0.287389     0.550684
# YearBuilt        0.391452    0.478954    0.537850   0.199010     0.572323
# TotRmsAbvGrd     0.285573    0.337822    0.362289   0.825489     0.427452
# FullBath         0.323722    0.405656    0.469672   0.630012     0.550600
# 1stFlrSF         0.819530    0.489782    0.439317   0.566024     0.476224
# TotalBsmtSF      1.000000    0.486665    0.434585   0.454868     0.537808
# GarageArea       0.486665    1.000000    0.882475   0.468997     0.562022
# GarageCars       0.434585    0.882475    1.000000   0.467247     0.600671
# GrLivArea        0.454868    0.468997    0.467247   1.000000     0.593007
# OverallQual      0.537808    0.562022    0.600671   0.593007     1.000000
# SalePrice        0.613581    0.623431    0.640409   0.708624     0.790982
#
#               SalePrice
# YearRemodAdd   0.507101
# YearBuilt      0.522897
# TotRmsAbvGrd   0.533723
# FullBath       0.560664
# 1stFlrSF       0.605852
# TotalBsmtSF    0.613581
# GarageArea     0.623431
# GarageCars     0.640409
# GrLivArea      0.708624
# OverallQual    0.790982
# SalePrice      1.000000

# %%
sns.heatmap(df_top.corr())

# %%
e=X_corr.loc['SalePrice'].sort_values()[-11: -1]
e
# Out:
# YearRemodAdd    0.507101
# YearBuilt       0.522897
# TotRmsAbvGrd    0.533723
# FullBath        0.560664
# 1stFlrSF        0.605852
# TotalBsmtSF     0.613581
# GarageArea      0.623431
# GarageCars      0.640409
# GrLivArea       0.708624
# OverallQual     0.790982
# Name: SalePrice, dtype: float64

# %%
df_number.loc[: , e.index].head()
# Out:
#    YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  TotalBsmtSF  \
# 0          2003       2003             8         2       856          856
# 1          1976       1976             6         2      1262         1262
# 2          2002       2001             6         2       920          920
# 3          1970       1915             7         1       961          756
# 4          2000       2000             9         2      1145         1145
#
#    GarageArea  GarageCars  GrLivArea  OverallQual
# 0         548           2       1710            7
# 1         460           2       1262            6
# 2         608           2       1786            7
# 3         642           3       1717            7
# 4         836           3       2198            8

# %%
df_number.loc[: , e.index].head().corr()
# Out:
#               YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  \
# YearRemodAdd      1.000000   0.886424      0.420167  0.711056 -0.400546
# YearBuilt         0.886424   1.000000      0.240723  0.955671 -0.018221
# TotRmsAbvGrd      0.420167   0.240723      1.000000  0.085749 -0.073541
# FullBath          0.711056   0.955671      0.085749  1.000000  0.224332
# 1stFlrSF         -0.400546  -0.018221     -0.073541  0.224332  1.000000
# TotalBsmtSF      -0.011856   0.403473     -0.021780  0.618458  0.904530
# GarageArea        0.324679   0.077250      0.731845 -0.092838  0.000453
# GarageCars       -0.298910  -0.524266      0.560112 -0.612372  0.130756
# GrLivArea         0.563748   0.257566      0.763658  0.029609 -0.251655
# OverallQual       0.534310   0.226657      0.813489  0.000000 -0.244838
#
#               TotalBsmtSF  GarageArea  GarageCars  GrLivArea  OverallQual
# YearRemodAdd    -0.011856    0.324679   -0.298910   0.563748     0.534310
# YearBuilt        0.403473    0.077250   -0.524266   0.257566     0.226657
# TotRmsAbvGrd    -0.021780    0.731845    0.560112   0.763658     0.813489
# FullBath         0.618458   -0.092838   -0.612372   0.029609     0.000000
# 1stFlrSF         0.904530    0.000453    0.130756  -0.251655    -0.244838
# TotalBsmtSF      1.000000   -0.040257   -0.162514  -0.189971    -0.197430
# GarageArea      -0.040257    1.000000    0.785466   0.950463     0.951604
# GarageCars      -0.162514    0.785466    1.000000   0.612367     0.645497
# GrLivArea       -0.189971    0.950463    0.612367   1.000000     0.995917
# OverallQual     -0.197430    0.951604    0.645497   0.995917     1.000000

# %%
df_number.loc[: , e.index].head().corr().sort_values()
# Out:
# ----------------------------------------------------
# TypeError          Traceback (most recent call last)
# <ipython-input-43-9d1924b115c0> in <module>()
# ----> 1 df_number.loc[: , e.index].head().corr().sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
sns.heatmap(df_number.loc[: , e.index].head().corr())

# %%
"""
選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
"""

# %%
"""
選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

補足
重回帰分析などで予測する場合、相関が高すぎる特徴量の組み合わせがあると予測に悪影響が出ることがあります。
このような場合の簡単な対処方法として、そういった特徴量の組みを探し出して、１つに絞るということがあります。
"""
