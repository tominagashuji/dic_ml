# %% [markdown]
# ### 問題１
#
# Home Creditはどのような企業？

# %% [markdown]
# 回答＿その顧客が返済能力があるかどうかを予測する。

# %% [markdown]
# このコンペティションでは何を予測する？

# %% [markdown]
# 回答＿返済能力を予測する。

# %% [markdown]
# それを予測することで企業が得られるメリットは何？

# %% [markdown]
# 返済予測のデータセットを得ることができる。
# 銀行、顧客双方にメリットを与えることができる。

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("application_train.csv")
df
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...

# %%
df.shape
# Out:
# (307511, 122)

# %% [markdown]
# ### 【問題2】データの概観の把握
# データの概観を把握するために以下のようなことを行ってください。
# .head()、.info()、describe()などを使う
# 欠損値の有無を見る
# クラスごとのデータ数をグラフに出す
# それぞれ結果に対する説明や考察も行ってください。

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                         0
# TARGET                             0
# NAME_CONTRACT_TYPE                 0
# CODE_GENDER                        0
# FLAG_OWN_CAR                       0
# FLAG_OWN_REALTY                    0
# CNT_CHILDREN                       0
# AMT_INCOME_TOTAL                   0
# AMT_CREDIT                         0
# AMT_ANNUITY                       12
# AMT_GOODS_PRICE                  278
# NAME_TYPE_SUITE                 1292
# NAME_INCOME_TYPE                   0
# NAME_EDUCATION_TYPE                0
# NAME_FAMILY_STATUS                 0
# NAME_HOUSING_TYPE                  0
# REGION_POPULATION_RELATIVE         0
# DAYS_BIRTH                         0
# DAYS_EMPLOYED                      0
# DAYS_REGISTRATION                  0
# DAYS_ID_PUBLISH                    0
# OWN_CAR_AGE                   202929
# FLAG_MOBIL                         0
# FLAG_EMP_PHONE                     0
# FLAG_WORK_PHONE                    0
# ...

# %%
#sns.barplot(x=df.columns, data=df[df["TARGET"]==1].count())
plt.bar(df[df["TARGET"]==1].count(),)
# Out:
# --------------------------------------------------
# TypeError        Traceback (most recent call last)
# <ipython-input-8-43c88c3d62c8> in <module>()
#       1 #sns.barplot(x=df.columns, data=df[df["TARGET"]==1].count())
# ----> 2 plt.bar(df[df["TARGET"]==1].count(),)
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(*args, **kwargs)
#    2646                       mplDeprecation)
#    2647     try:
# -> 2648         ret = ax.bar(*args, **kwargs)
#    2649     finally:
#    2650         ax._hold = washold
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ...

# %%
df[df["TARGET"]==1].count()
# Out:
# SK_ID_CURR                    24825
# TARGET                        24825
# NAME_CONTRACT_TYPE            24825
# CODE_GENDER                   24825
# FLAG_OWN_CAR                  24825
# FLAG_OWN_REALTY               24825
# CNT_CHILDREN                  24825
# AMT_INCOME_TOTAL              24825
# AMT_CREDIT                    24825
# AMT_ANNUITY                   24825
# AMT_GOODS_PRICE               24804
# NAME_TYPE_SUITE               24755
# NAME_INCOME_TYPE              24825
# NAME_EDUCATION_TYPE           24825
# NAME_FAMILY_STATUS            24825
# NAME_HOUSING_TYPE             24825
# REGION_POPULATION_RELATIVE    24825
# DAYS_BIRTH                    24825
# DAYS_EMPLOYED                 24825
# DAYS_REGISTRATION             24825
# DAYS_ID_PUBLISH               24825
# OWN_CAR_AGE                    7576
# FLAG_MOBIL                    24825
# FLAG_EMP_PHONE                24825
# FLAG_WORK_PHONE               24825
# FLAG_CONT_MOBILE              24825
# ...

# %%
df_corr_target =
