# %%
"""
【課題】富士山を超える最小の折る回数
"""
PAPER = 0.00008
MT_FUJI_HIGHT = 3776
paper_hight = PAPER
fold_count = 0

while True:
    if paper_hight > MT_FUJI_HIGHT:
        break

    fold_count += 1
    paper_hight *= 2
    print("{}回折った時に、{}メートルになり富士山の高さを超える！！".format(fold_count,paper_hight))

print("{}回折った時に、{:.1f}メートルになり富士山の高さを超える！！".format(fold_count,paper_hight))
# print(paper_hight)
# Out:
# 1回折った時に、0.00016メートルになり富士山の高さを超える！！
# 2回折った時に、0.00032メートルになり富士山の高さを超える！！
# 3回折った時に、0.00064メートルになり富士山の高さを超える！！
# 4回折った時に、0.00128メートルになり富士山の高さを超える！！
# 5回折った時に、0.00256メートルになり富士山の高さを超える！！
# 6回折った時に、0.00512メートルになり富士山の高さを超える！！
# 7回折った時に、0.01024メートルになり富士山の高さを超える！！
# 8回折った時に、0.02048メートルになり富士山の高さを超える！！
# 9回折った時に、0.04096メートルになり富士山の高さを超える！！
# 10回折った時に、0.08192メートルになり富士山の高さを超える！！
# 11回折った時に、0.16384メートルになり富士山の高さを超える！！
# 12回折った時に、0.32768メートルになり富士山の高さを超える！！
# 13回折った時に、0.65536メートルになり富士山の高さを超える！！
# 14回折った時に、1.31072メートルになり富士山の高さを超える！！
# 15回折った時に、2.62144メートルになり富士山の高さを超える！！
# 16回折った時に、5.24288メートルになり富士山の高さを超える！！
# 17回折った時に、10.48576メートルになり富士山の高さを超える！！
# 18回折った時に、20.97152メートルになり富士山の高さを超える！！
# 19回折った時に、41.94304メートルになり富士山の高さを超える！！
# 20回折った時に、83.88608メートルになり富士山の高さを超える！！
# 21回折った時に、167.77216メートルになり富士山の高さを超える！！
# 22回折った時に、335.54432メートルになり富士山の高さを超える！！
# 23回折った時に、671.08864メートルになり富士山の高さを超える！！
# 24回折った時に、1342.17728メートルになり富士山の高さを超える！！
# 25回折った時に、2684.35456メートルになり富士山の高さを超える！！
# 26回折った時に、5368.70912メートルになり富士山の高さを超える！！
# ...

# %%
"""
【課題】任意の厚さに対応した関数を作成
t0 は PAPER
参考URL：
http://aoki2.si.gunma-u.ac.jp/Hanasi/StatTalk/fudoushousuu.html
e+16の意味→10の１６乗

"""
def manual_thickness(input_thickness,one_thickness):

#     初期処理（一枚の厚さ、折った紙の高さ、折った回数）
    PAPER = one_thickness
    paper_hight = PAPER
    fold_count = 0

#     任意の高さを超えるまで繰り返し、折った回数のカウント
    while True:
        if input_thickness < paper_hight:
            break
        else:
            fold_count += 1
            paper_hight *= 2
            print ("{}折ると、高さは{}になる。".format(fold_count,paper_hight))

    pass
    return fold_count,paper_hight

# 任意の高さを入力する。
print("任意の高さをメートルで入力してね！！^ - ^")
print("最も近い太陽以外の恒星はプロキシマ・ケンタウリといい、距離は4.243光年で、4.01419e+16メートル！！^ - ^；")
print("つまり、、401419000000000000000メートル！！^ - ^；")
input_hight = input()

# 紙の厚さの初期値を入力する。
print("紙の厚さを入力してね！！！（通常 0.00008m）")
input_thickness = input()

# # *9460730472580800
# takasa = 4.243 * 9460730472580800
# print("aaa")
# print(takasa)

# 入力した値は文字型になっているので数値型にして引数を渡す
# returnされた返り値を左辺に取得
fold_count , paper_hight = manual_thickness(float(input_hight),float(input_thickness))

# 返り値を出力
print ("{}折ると、高さは{}になる。".format(fold_count,paper_hight))
# Out:
# 任意の高さをメートルで入力してね！！^ - ^
# 最も近い太陽以外の恒星はプロキシマ・ケンタウリといい、距離は4.243光年で、4.01419e+16メートル！！^ - ^；
# つまり、、401419000000000000000メートル！！^ - ^；
# 401419000000000000000
# 紙の厚さを入力してね！！！（通常 0.00008m）
# 0.00008
# 1折ると、高さは0.00016になる。
# 2折ると、高さは0.00032になる。
# 3折ると、高さは0.00064になる。
# 4折ると、高さは0.00128になる。
# 5折ると、高さは0.00256になる。
# 6折ると、高さは0.00512になる。
# 7折ると、高さは0.01024になる。
# 8折ると、高さは0.02048になる。
# 9折ると、高さは0.04096になる。
# 10折ると、高さは0.08192になる。
# 11折ると、高さは0.16384になる。
# 12折ると、高さは0.32768になる。
# 13折ると、高さは0.65536になる。
# 14折ると、高さは1.31072になる。
# 15折ると、高さは2.62144になる。
# 16折ると、高さは5.24288になる。
# 17折ると、高さは10.48576になる。
# 18折ると、高さは20.97152になる。
# 19折ると、高さは41.94304になる。
# 20折ると、高さは83.88608になる。
# 21折ると、高さは167.77216になる。
# 22折ると、高さは335.54432になる。
# 23折ると、高さは671.08864になる。
# 24折ると、高さは1342.17728になる。
# 25折ると、高さは2684.35456になる。
# 26折ると、高さは5368.70912になる。
# 27折ると、高さは10737.41824になる。
# 28折ると、高さは21474.83648になる。
# 29折ると、高さは42949.67296になる。
# 30折ると、高さは85899.34592になる。
# 31折ると、高さは171798.69184になる。
# 32折ると、高さは343597.38368になる。
# 33折ると、高さは687194.76736になる。
# ...

# %%
"""
【課題】必要な紙の長さ
L = (pai * t0) / 6 *((2**n) + 4)*((2**n) - 1)

参考URL：
https://python.atelierkobato.com/pi/

月：43回折る→n=43
富士山：26回折る→n=26
最も近い太陽以外の恒星：83回折る→n=83
"""

def how_length_paper(fold_time):
    # 初期処理
    # pythonで用意されているπを用意
    import math
    pai = math.pi
    #     print("pai = {}".format(pai))
    PAPER = 0.00008

    # 折る回数は判明しているので、これを元に必要な長さを算出する
    paper_length = (pai * PAPER) / 6 *((2**fold_time) + 4)*((2**fold_time) - 1)

    pass
    return paper_length

# 折った回数を入力し、引数として関数に渡す
# 月：43回折る→n=43
# 富士山：26回折る→n=26
# 最も近い太陽以外の恒星：83回折る→n=83
print("紙を折る回数を入力してください〜m(_ _)m")
fold_time = input()
paper_length = how_length_paper(float(fold_time))

print("紙の長さは{:.6f}mです！".format(paper_length))
# Out:
# 紙を折る回数を入力してください〜m(_ _)m
# 83
# 紙の長さは3918031195347814012733596754230962159775383552.000000mです！

# %%
"""
【課題２の修正】任意の厚さに対応した関数を作成
t0 は PAPER
参考URL：
http://aoki2.si.gunma-u.ac.jp/Hanasi/StatTalk/fudoushousuu.html
e+16の意味→10の１６乗

光年の正しいメートル換算をして再計算したい

"""
def manual_thickness(input_thickness,one_thickness):

#     初期処理（一枚の厚さ、折った紙の高さ、折った回数）
    PAPER = one_thickness
    paper_hight = PAPER
    fold_count = 0

#     任意の高さを超えるまで繰り返し、折った回数のカウント
    while True:
        if input_thickness < paper_hight:
            break
        else:
            fold_count += 1
            paper_hight *= 2
            print ("{}折ると、高さは{}になる。".format(fold_count,paper_hight))

    pass
    return fold_count,paper_hight

# 任意の高さを入力する。
print("任意の高さをメートルで入力してね！！^ - ^")
print("最も近い太陽以外の恒星はプロキシマ・ケンタウリといい、距離は4.243光年（光年：9460730472580800 m（正確に））！！^ - ^；")
print("つまり、、4.014187939516034e+16メートル！！^ - ^；")
input_hight = input()

# 紙の厚さの初期値を入力する。
print("紙の厚さを入力してね！！！（通常 0.00008m）")
input_thickness = input()

# # *9460730472580800
# takasa = 4.243 * 9460730472580800
# print("aaa")
# print(takasa)

# 入力した値は文字型になっているので数値型にして引数を渡す
# returnされた返り値を左辺に取得
fold_count , paper_hight = manual_thickness(float(input_hight),float(input_thickness))

# 返り値を出力
print ("{}折ると、高さは{}になる。".format(fold_count,paper_hight))
# Out:
# 任意の高さをメートルで入力してね！！^ - ^
# 最も近い太陽以外の恒星はプロキシマ・ケンタウリといい、距離は4.243光年（光年：9460730472580800 m（正確に））！！^ - ^；
# つまり、、4.014187939516034e+16メートル！！^ - ^；
# 3918031195347814012733596754230962159775383552.000000
# 紙の厚さを入力してね！！！（通常 0.00008m）
# 0.00008
# 1折ると、高さは0.00016になる。
# 2折ると、高さは0.00032になる。
# 3折ると、高さは0.00064になる。
# 4折ると、高さは0.00128になる。
# 5折ると、高さは0.00256になる。
# 6折ると、高さは0.00512になる。
# 7折ると、高さは0.01024になる。
# 8折ると、高さは0.02048になる。
# 9折ると、高さは0.04096になる。
# 10折ると、高さは0.08192になる。
# 11折ると、高さは0.16384になる。
# 12折ると、高さは0.32768になる。
# 13折ると、高さは0.65536になる。
# 14折ると、高さは1.31072になる。
# 15折ると、高さは2.62144になる。
# 16折ると、高さは5.24288になる。
# 17折ると、高さは10.48576になる。
# 18折ると、高さは20.97152になる。
# 19折ると、高さは41.94304になる。
# 20折ると、高さは83.88608になる。
# 21折ると、高さは167.77216になる。
# 22折ると、高さは335.54432になる。
# 23折ると、高さは671.08864になる。
# 24折ると、高さは1342.17728になる。
# 25折ると、高さは2684.35456になる。
# 26折ると、高さは5368.70912になる。
# 27折ると、高さは10737.41824になる。
# 28折ると、高さは21474.83648になる。
# 29折ると、高さは42949.67296になる。
# 30折ると、高さは85899.34592になる。
# 31折ると、高さは171798.69184になる。
# ...
