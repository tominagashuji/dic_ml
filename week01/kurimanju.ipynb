# %%
"""
【問題】栗まんじゅうが太陽系を覆う日
饅頭の体積：直径5cm（0.05m）の球
太陽の体積：直径140万kmの球
球体の体積の求め方：V=4/3*π*(r**3)
"""
# 計算で必要なπを使用できるようにする
import math
pai = math.pi

# 饅頭と太陽の半径を算出（メートルで統一）
MANJU_RADIUS = 0.025
SUN_RADIUS = 75*(10**7)

def wharf_covers_the_sun():

    #     初期処理を実施
    volume = 0
    minutes = 0
    
    #     饅頭と太陽の体積を算出
    manju_volume = (4/3)*pai*(MANJU_RADIUS**3)
    sun_volume = (4/3)*pai*(SUN_RADIUS**3)
    #     念のため体積を確認
    #     print(manju_volume)
    #     print(sun_volume)

    #     饅頭の体積が太陽を超えるまで繰り返し実施
    while True:
        if manju_volume  > sun_volume:
            break
        else:
            #     饅頭は5分毎に倍に大きくなる
            minutes += 5
            manju_volume *= 2
            print("時間{}、饅頭体積{}".format(minutes,manju_volume))

    pass
    return minutes,manju_volume

minutes,manju_volume = wharf_covers_the_sun()
print("饅頭が太陽を覆うのは{}分後です！！！( ；∀；)<ｺﾜｲｰ！！！大きさは{:.1f}立方メートルです！！！".format(minutes,manju_volume))
# Out:
# 時間5、饅頭体積0.00013089969389957473
# 時間10、饅頭体積0.00026179938779914946
# 時間15、饅頭体積0.0005235987755982989
# 時間20、饅頭体積0.0010471975511965978
# 時間25、饅頭体積0.0020943951023931957
# 時間30、饅頭体積0.004188790204786391
# 時間35、饅頭体積0.008377580409572783
# 時間40、饅頭体積0.016755160819145565
# 時間45、饅頭体積0.03351032163829113
# 時間50、饅頭体積0.06702064327658226
# 時間55、饅頭体積0.13404128655316452
# 時間60、饅頭体積0.26808257310632905
# 時間65、饅頭体積0.5361651462126581
# 時間70、饅頭体積1.0723302924253162
# 時間75、饅頭体積2.1446605848506324
# 時間80、饅頭体積4.289321169701265
# 時間85、饅頭体積8.57864233940253
# 時間90、饅頭体積17.15728467880506
# 時間95、饅頭体積34.31456935761012
# 時間100、饅頭体積68.62913871522024
# 時間105、饅頭体積137.25827743044047
# 時間110、饅頭体積274.51655486088094
# 時間115、饅頭体積549.0331097217619
# 時間120、饅頭体積1098.0662194435238
# 時間125、饅頭体積2196.1324388870476
# 時間130、饅頭体積4392.264877774095
# 時間135、饅頭体積8784.52975554819
# 時間140、饅頭体積17569.05951109638
# 時間145、饅頭体積35138.11902219276
# 時間150、饅頭体積70276.23804438552
# 時間155、饅頭体積140552.47608877104
# 時間160、饅頭体積281104.9521775421
# ...

# %%
"""
【問題】栗まんじゅうが太陽系を覆う日
グラフ化
"""
# 計算で必要なπを使用できるようにする
import math
pai = math.pi

# 饅頭と太陽の半径を算出（メートルで統一）
MANJU_RADIUS = 0.025
SUN_RADIUS = 75*(10**7)

def wharf_covers_the_sun():

    #     初期処理を実施
    volume = 0
    minutes = 0

    #     饅頭と太陽の体積を算出、饅頭の体積の初期値を保持
    manju_volume = (4/3)*pai*(MANJU_RADIUS**3)
    sun_volume = (4/3)*pai*(SUN_RADIUS**3)
    manju_volume_list = [manju_volume]

    #     念のため体積を確認
    #     print(manju_volume)
    #     print(sun_volume)

    #     饅頭の体積が太陽を超えるまで繰り返し実施
    while True:
        if manju_volume  > sun_volume:
            break
        else:
            #     饅頭は5分毎に倍に大きくなる
            minutes += 5
            #     1,2,3,4分までは同じ大きさ
            for i in range (4):
                manju_volume_list.append(manju_volume)

                #     饅頭はべき乗で大きくなる
            manju_volume *= 2
            #     大きくなった饅頭の大きさを5分後のリストに格納
            manju_volume_list.append(manju_volume)
            #             print("時間{}、饅頭体積{}".format(minutes,manju_volume))

    pass
    return minutes,manju_volume,manju_volume_list

minutes,manju_volume,manju_volume_list = wharf_covers_the_sun()
# print("饅頭が太陽を覆うのは{}分後です！！！( ；∀；)<ｺﾜｲｰ".format(minutes))

import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("wharf_covers_the_sun")
plt.xlabel("minutes")
plt.ylabel("manju_volume")
plt.plot(manju_volume_list,color='pink', marker='o', linestyle='dashed',
         linewidth=2, markersize=12)
plt.show()

# %%
"""
【問題】栗まんじゅうが太陽系を覆う日
覆う物の調整
"""
# 計算で必要なπを使用できるようにする
import math
pai = math.pi

# 饅頭と太陽の半径を算出（メートルで統一）
MANJU_RADIUS = 0.025
SUN_RADIUS = 75*(10**7)

def wharf_covers_the_sun(something_radius):

    #     初期処理を実施
    volume = 0
    minutes = 0

    #     饅頭と太陽の体積を算出、饅頭の体積の初期値を保持
    manju_volume = (4/3)*pai*(MANJU_RADIUS**3)
    something_volume = (4/3)*pai*(something_radius**3)
    manju_volume_list = [manju_volume]

    #     念のため体積を確認
    #     print(manju_volume)
    #     print(sun_volume)

    #     饅頭の体積が太陽を超えるまで繰り返し実施
    while True:
        if manju_volume  > something_volume:
            break
        else:
            #     饅頭は5分毎に倍に大きくなる
            minutes += 5
            #     1,2,3,4分後までは同じ大きさ
            for i in range (4):
                manju_volume_list.append(manju_volume)

            #     饅頭はべき乗で大きくなる
            manju_volume *= 2
            #     大きくなった饅頭の大きさを5分後のリストに格納
            manju_volume_list.append(manju_volume)
            print("時間{}、饅頭体積{}".format(minutes,manju_volume))

    #     処理が終了したら値を返す。
    pass
    return minutes,manju_volume,manju_volume_list

#     大きくなった饅頭の大きさを5分後のリストに格納
print("饅頭で覆いたい何かの半径を入力してくれよな！！！٩( ᐛ )و")
print("参考程度に東京ドームは直径244mだから半径122m程度！！！٩( ᐛ )و")
input_radius = input()

minutes,manju_volume,manju_volume_list = wharf_covers_the_sun(float(input_radius))
print("饅頭が何かを覆うのは{}分後です！！！( ；∀；)<ｺﾜｲｰ！！！大きさは{:.1f}立方メートルです！！！".format(minutes,manju_volume))

import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("wharf_covers_the_sun")
plt.xlabel("minutes")
plt.ylabel("manju_volume")
plt.plot(manju_volume_list,color='pink', marker='x', linestyle='dashed',
         linewidth=2, markersize=12)
plt.show()
# Out:
# 饅頭で覆いたい何かの半径を入力してくれよな！！！٩( ᐛ )و
# 参考程度に東京ドームは直径244mだから半径122m程度！！！٩( ᐛ )و
# 122
# 時間5、饅頭体積0.00013089969389957473
# 時間10、饅頭体積0.00026179938779914946
# 時間15、饅頭体積0.0005235987755982989
# 時間20、饅頭体積0.0010471975511965978
# 時間25、饅頭体積0.0020943951023931957
# 時間30、饅頭体積0.004188790204786391
# 時間35、饅頭体積0.008377580409572783
# 時間40、饅頭体積0.016755160819145565
# 時間45、饅頭体積0.03351032163829113
# 時間50、饅頭体積0.06702064327658226
# 時間55、饅頭体積0.13404128655316452
# 時間60、饅頭体積0.26808257310632905
# 時間65、饅頭体積0.5361651462126581
# 時間70、饅頭体積1.0723302924253162
# 時間75、饅頭体積2.1446605848506324
# 時間80、饅頭体積4.289321169701265
# 時間85、饅頭体積8.57864233940253
# 時間90、饅頭体積17.15728467880506
# 時間95、饅頭体積34.31456935761012
# 時間100、饅頭体積68.62913871522024
# 時間105、饅頭体積137.25827743044047
# 時間110、饅頭体積274.51655486088094
# 時間115、饅頭体積549.0331097217619
# 時間120、饅頭体積1098.0662194435238
# 時間125、饅頭体積2196.1324388870476
# 時間130、饅頭体積4392.264877774095
# 時間135、饅頭体積8784.52975554819
# 時間140、饅頭体積17569.05951109638
# 時間145、饅頭体積35138.11902219276
# ...
